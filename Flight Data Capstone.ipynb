# %%
import pandas as pd
import json
import requests
import gzip
import csv

# %%
from opensky_api import OpenSkyApi
api = OpenSkyApi()
states = api.get_states()

# %%
#adding all the individual dataframes for historical flight data during covid

covid_201901 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190101_20190131.csv.gz', 
                           compression='gzip')
covid_201902 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190201_20190228.csv.gz', 
                           compression='gzip')
covid_201903 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190301_20190331.csv.gz', 
                           compression='gzip')
covid_201904 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190401_20190430.csv.gz', 
                           compression='gzip')
covid_201905 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190501_20190531.csv.gz', 
                           compression='gzip')
covid_201906 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190601_20190630.csv.gz', 
                           compression='gzip')
covid_201907 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190701_20190731.csv.gz', 
                           compression='gzip')
covid_201908 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190801_20190831.csv.gz', 
                           compression='gzip')
covid_201909 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20190901_20190930.csv.gz', 
                           compression='gzip')
covid_201910 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20191001_20191031.csv.gz', 
                           compression='gzip')
covid_201911 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20191101_20191130.csv.gz', 
                           compression='gzip')
covid_201912 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20191201_20191231.csv.gz', 
                           compression='gzip')
covid_202001 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200101_20200131.csv.gz', 
                           compression='gzip')
covid_202002 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200201_20200229.csv.gz', 
                           compression='gzip')
covid_202003 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200301_20200331.csv.gz', 
                           compression='gzip')
covid_202004 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200401_20200430.csv.gz', 
                           compression='gzip')
covid_202005 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200501_20200531.csv.gz', 
                           compression='gzip')
covid_202006 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200601_20200630.csv.gz', 
                           compression='gzip')
covid_202007 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200701_20200731.csv.gz', 
                           compression='gzip')
covid_202008 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200801_20200831.csv.gz', 
                           compression='gzip')
covid_202009 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20200901_20200930.csv.gz', 
                           compression='gzip')
covid_202010 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20201001_20201031.csv.gz', 
                           compression='gzip')
covid_202011 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20201101_20201130.csv.gz', 
                           compression='gzip')
covid_202012 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20201201_20201231.csv.gz', 
                           compression='gzip')
covid_202101 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210101_20210131.csv.gz', 
                           compression='gzip')
covid_202102 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210201_20210228.csv.gz', 
                            compression='gzip')
covid_202103 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210301_20210331.csv.gz', 
                           compression='gzip')
covid_202104 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210401_20210430.csv.gz', 
                           compression='gzip')
covid_202105 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210501_20210530.csv.gz', 
                           compression='gzip')
covid_202106 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210601_20210630.csv.gz', 
                           compression='gzip')
covid_202107 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210701_20210731.csv.gz', 
                           compression='gzip')
covid_202108 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210801_20210831.csv.gz', 
                           compression='gzip')
covid_202109 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20210901_20210930.csv.gz', 
                           compression='gzip')
covid_202110 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20211001_20211031.csv.gz', 
                           compression='gzip')
covid_202111 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20211101_20211130.csv.gz', 
                           compression='gzip')
covid_202112 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20211201_20211231.csv.gz', 
                           compression='gzip')
covid_202201 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20220101_20220131.csv.gz', 
                           compression='gzip')
covid_202202 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20220201_20220228.csv.gz', 
                           compression='gzip')
covid_202203 = pd.read_csv('/Users/olivianystrom/Desktop/Springboard/Capstone 3/flightlist_20220301_20220331.csv.gz', 
                           compression='gzip')
# Out:
# /Users/olivianystrom/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
covidList = []
covidList.extend(value for name, value in locals().items() if name.startswith('covid_20'))
covid_df = pd.concat(covidList)
covid_df.columns = covid_df.columns.str.upper()
covid_df = covid_df.rename(columns={"NUMBER": "AIR_NUMBER", "DAY": "FLIGHT_DATE"})
covid_df.head()
# Out:
#   CALLSIGN AIR_NUMBER  ICAO24 REGISTRATION TYPECODE ORIGIN DESTINATION  \
# 0    HVN19        NaN  888152          NaN      NaN   YMML        LFPG
# 1   CCA839        NaN  780ad1          NaN      NaN   YMML        LEBL
# 2   CES219        NaN  780b7e       B-5936     A332   YSSY        EDDF
# 3   AEA040        NaN  34444e       EC-LVL     A332   LEMD        LEMD
# 4   CXA825        NaN  780d75       B-2760     B788   YSSY        LFPG
#
#                    FIRSTSEEN                   LASTSEEN  \
# 0  2018-12-31 00:43:16+00:00  2019-01-01 04:56:29+00:00
# 1  2018-12-31 00:53:08+00:00  2019-01-01 06:01:42+00:00
# 2  2018-12-31 01:05:29+00:00  2019-01-01 04:09:29+00:00
# 3  2018-12-31 01:07:21+00:00  2019-01-01 03:32:59+00:00
# 4  2018-12-31 01:18:29+00:00  2019-01-01 04:32:28+00:00
#
#                  FLIGHT_DATE  LATITUDE_1  LONGITUDE_1  ALTITUDE_1  LATITUDE_2  \
# 0  2019-01-01 00:00:00+00:00  -37.659485   144.804421       304.8   48.995316
# ...

# %%
r = requests.get('https://opensky-network.org/api/states/all')
print(r.headers)
print(r.status_code)
# Out:
# {'Server': 'nginx/1.17.6', 'Date': 'Fri, 27 May 2022 23:07:07 GMT', 'Content-Type': 'application/json;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-cache, no-store, max-age=0, must-revalidate', 'Pragma': 'no-cache', 'Expires': '0', 'X-Frame-Options': 'DENY', 'Set-Cookie': 'XSRF-TOKEN=76dcd304-5605-4c30-90a7-acdff3f01f89; Path=/', 'Content-Encoding': 'gzip'}
# 200

# %%
with open('json_data.json', 'w') as outfile:
    json.dump(r.json(), outfile)

# %%
df = pd.read_json('json_data.json')

# %%
df.head()
# Out:
#          time                                             states
# 0  1653692826  [a6fe0f, N55LC   , United States, 1653692825, ...
# 1  1653692826  [e8027d, LPE2236 , Chile, 1653692538, 16536925...
# 2  1653692826  [aa56db, UAL2346 , United States, 1653692825, ...
# 3  1653692826  [7c6b2f, JST930  , Australia, 1653692826, 1653...
# 4  1653692826  [7c6b2d, JST730  , Australia, 1653692826, 1653...

# %%
keys = ["icao24", "callsign", "origin_country", "time_position",
            "last_contact", "longitude", "latitude", "baro_altitude", "on_ground",
            "velocity", "true_track", "vertical_rate", "sensors",
            "geo_altitude", "squawk", "spi", "position_source"]

df = pd.DataFrame(df["states"].to_list(), columns=keys)

columns = ["icao24", "callsign", "origin_country", "last_contact", 
           "longitude", "latitude", "baro_altitude", "on_ground",
           "velocity"]
df = df[columns]
df.head(10)
# Out:
#    icao24  callsign origin_country  last_contact  longitude  latitude  \
# 0  a6fe0f  N55LC     United States    1653692826   -81.6423   30.8531
# 1  e8027d  LPE2236           Chile    1653692541   -76.4997   -9.0809
# 2  aa56db  UAL2346   United States    1653692826   -83.7303   32.3254
# 3  7c6b2f  JST930        Australia    1653692826   152.9100  -27.3952
# 4  7c6b2d  JST730        Australia    1653692826   145.5025  -38.2964
# 5  aa9321  UAL880    United States    1653692822   -94.8921   30.8725
# 6  7c6b2b  JST783        Australia    1653692826   151.8925  -30.3653
# 7  a57b27  WGN5871   United States    1653692620   144.9385   37.9203
# 8  a77ec5  EJA582    United States    1653692826  -113.7816   38.7924
# 9  7c6b40  JST759        Australia    1653692826   150.0163  -36.7972
#
#    baro_altitude  on_ground  velocity
# 0       13106.40      False    249.08
# 1       11582.40      False    231.40
# 2       10972.80      False    240.84
# 3        3962.40      False    151.62
# ...

# %%
#Metadata info
open("/Users/olivianystrom/Desktop/Springboard/Capstone 3/aircraftDatabase.csv")
df_meta = pd.read_csv("/Users/olivianystrom/Desktop/Springboard/Capstone 3/aircraftDatabase.csv")

# %%
print(df_meta.columns)
# columns = ['icao24', 'registration', 'manufacturericao', 'manufacturername',
#        'model', 'typecode', 'serialnumber', 'linenumber', 'icaoaircrafttype',
#        'operator', 'operatorcallsign', 'operatoricao', 'operatoriata', 'owner',
#        'testreg', 'registered', 'reguntil', 'status', 'built',
#        'firstflightdate', 'seatconfiguration', 'engines', 'modes', 'adsb',
#        'acars', 'notes', 'categoryDescription']
columns = ['icao24', 'registration', 'manufacturericao', 'manufacturername',
       'model', 'typecode', 'serialnumber', 'linenumber', 'icaoaircrafttype',
       'operator', 'operatorcallsign', 'operatoricao', 'operatoriata', 'owner',
       'testreg', 'registered', 'built','firstflightdate', 'engines',
       'notes', 'categoryDescription']
df_meta = df_meta[columns]
# Out:
# Index(['icao24', 'registration', 'manufacturericao', 'manufacturername',
#        'model', 'typecode', 'serialnumber', 'linenumber', 'icaoaircrafttype',
#        'operator', 'operatorcallsign', 'operatoricao', 'operatoriata', 'owner',
#        'testreg', 'registered', 'reguntil', 'status', 'built',
#        'firstflightdate', 'seatconfiguration', 'engines', 'modes', 'adsb',
#        'acars', 'notes', 'categoryDescription'],
#       dtype='object')

# %%
df = df.merge(df_meta, how = 'inner', on = 'icao24')
df.head()
# Out:
#    icao24  callsign origin_country  last_contact  longitude  latitude  \
# 0  a6fe0f  N55LC     United States    1653692826   -81.6423   30.8531
# 1  e8027d  LPE2236           Chile    1653692541   -76.4997   -9.0809
# 2  aa56db  UAL2346   United States    1653692826   -83.7303   32.3254
# 3  7c6b2f  JST930        Australia    1653692826   152.9100  -27.3952
# 4  7c6b2d  JST730        Australia    1653692826   145.5025  -38.2964
#
#    baro_altitude  on_ground  velocity registration  ... operatoricao  \
# 0       13106.40      False    249.08        N55LC  ...          NaN
# 1       11582.40      False    231.40       CC-BJE  ...          LPE
# 2       10972.80      False    240.84       N76529  ...          UAL
# 3        3962.40      False    151.62       VH-VGH  ...          JST
# 4        4739.64      False    157.45       VH-VGF  ...          JST
#
#   operatoriata                owner testreg registered       built  \
# ...

# %%
df_meta.columns = df_meta.columns.str.upper()
df_meta.dropna(subset = ["ICAO24"], inplace=True)
df_meta.head()
# Out:
#    ICAO24 REGISTRATION MANUFACTURERICAO               MANUFACTURERNAME  \
# 1  aa3487        N757F              NaN      Raytheon Aircraft Company
# 2  ae267b         6533           VOUGHT                   Aerospatiale
# 3  a4fa61        N42MH              NaN                          Piper
# 4  c04101       C-FYQA              NaN  Champion Aircraft Corporation
# 5  391927       F-GGJH            ROBIN                          Robin
#
#                   MODEL TYPECODE SERIALNUMBER LINENUMBER ICAOAIRCRAFTTYPE  \
# 1                   A36      NaN       E-3121        NaN              NaN
# 2        MH-65C Dolphin     AS65         6182        NaN              H2T
# 3             PA-31-350      NaN   31-7852015        NaN              NaN
# 4       7GCA (Champion)      NaN          420        NaN              NaN
# 5  DR.400 160 Chevalier     DR40         1795        NaN              L1P
#
#   OPERATOR  ... OPERATORICAO OPERATORIATA  \
# 1      NaN  ...          NaN          NaN
# ...

# %%
#Emergency situations

open("/Users/olivianystrom/Desktop/Springboard/Capstone 3/squawk7700_metadata.csv")
df_emergent = pd.read_csv("/Users/olivianystrom/Desktop/Springboard/Capstone 3/squawk7700_metadata.csv")


# flight_id: a unique identifier for each trajectory;
# callsign: ICAO flight callsign information;
# number: IATA flight number, when available;
# icao24, registration, typecode: information about the aircraft;
# origin: the origin airport for the aircraft, when available;
# landing: the airport where the aircraft actually landed, when available;
# destination: the intended destination airport, when available;
# diverted: the diversion airport, if applicable, when available;
# tweet_problem, tweet_result, tweet_fueldump: information extracted from Twitter accounts, about the nature of the issue, the consequence of the emergency and whether the aircraft is known to have dumped fuel;
# avh_id, avh_problem, avh_result, avh_fueldump: information extracted from The Aviation Herald, about the nature of the issue, the consequence of the emergency and whether the aircraft is known to have dumped fuel.
# The complete URL for each event is https://avherald.com/h?article={avh_id}&opt=1 (replace avh_id by the actual value)

# %%
print(df_emergent.head(10))
print(df_emergent.columns)
columns = ['flight_id', 'number', 'icao24', 'origin', 'landing', 'destination', 
           'diverted', 'tweet_problem', 'tweet_result', 'tweet_fueldump', 
           'avh_id', 'avh_problem', 'avh_result', 'avh_fueldump']
df_emergent = df_emergent[columns]
df_emergent = df_emergent.rename(columns={"number": "air_number"})
df_emergent.columns = df_emergent.columns.str.upper()
df_emergent = df_emergent.merge(df_meta, how = 'inner', on = 'ICAO24')
df_emergent.dtypes
# Out:
#           flight_id callsign  number  icao24 registration typecode origin  \
# 0  ARG1511_20180101  ARG1511  AR1511  e06442       LV-FQB     B738   SACO
# 1    DAL14_20180101    DAL14    DL14  a14c29       N183DN     B763   KATL
# 2   JBU263_20180108   JBU263   B6263  aa600a       N768JB     A320   KJFK
# 3    DAL65_20180108    DAL65    DL65  ab2855       N818NW     A333   KATL
# 4    EDW24_20180111    EDW24    WK24  4b1901       HB-JMF     A343   LSZH
# 5   ASA111_20180112   ASA111   AS111  a602ab       N487AS     B739   KLAS
# 6  ONE8511_20180113  ONE8511  O68511  e4919d       PR-OCX     A332   KMIA
# 7   BAW882_20180115   BAW882   BA882  406532       G-EUYM     A320   EGLL
# 8  ENY3342_20180117  ENY3342  AA3342  a272b8       N257NN     E75L   KDFW
# 9   WJA506_20180122   WJA506   WS506  c0499b       C-GBWS     B736   CYXE
#
#   landing destination diverted tweet_problem tweet_result tweet_fueldump  \
# 0    SABE        SABE      NaN           NaN          NaN            NaN
# ...

# %%
# df = df.merge(df_emergent, how = 'inner', on = 'icao24')

df.head()
# Out:
#    icao24  callsign origin_country  last_contact  longitude  latitude  \
# 0  a6fe0f  N55LC     United States    1653692826   -81.6423   30.8531
# 1  e8027d  LPE2236           Chile    1653692541   -76.4997   -9.0809
# 2  aa56db  UAL2346   United States    1653692826   -83.7303   32.3254
# 3  7c6b2f  JST930        Australia    1653692826   152.9100  -27.3952
# 4  7c6b2d  JST730        Australia    1653692826   145.5025  -38.2964
#
#    baro_altitude  on_ground  velocity registration  ... operatoricao  \
# 0       13106.40      False    249.08        N55LC  ...          NaN
# 1       11582.40      False    231.40       CC-BJE  ...          LPE
# 2       10972.80      False    240.84       N76529  ...          UAL
# 3        3962.40      False    151.62       VH-VGH  ...          JST
# 4        4739.64      False    157.45       VH-VGF  ...          JST
#
#   operatoriata                owner testreg registered       built  \
# ...

# %%
df.columns
# Out:
# Index(['icao24', 'callsign', 'origin_country', 'last_contact', 'longitude',
#        'latitude', 'baro_altitude', 'on_ground', 'velocity', 'registration',
#        'manufacturericao', 'manufacturername', 'model', 'typecode',
#        'serialnumber', 'linenumber', 'icaoaircrafttype', 'operator',
#        'operatorcallsign', 'operatoricao', 'operatoriata', 'owner', 'testreg',
#        'registered', 'built', 'firstflightdate', 'engines', 'notes',
#        'categoryDescription'],
#       dtype='object')

# %%
#Aircraft type info
open("/Users/olivianystrom/Desktop/Springboard/Capstone 3/doc8643AircraftTypes.csv")
df_types = pd.read_csv("/Users/olivianystrom/Desktop/Springboard/Capstone 3/doc8643AircraftTypes.csv")

# %%
#Manufacturer info
open("/Users/olivianystrom/Desktop/Springboard/Capstone 3/doc8643Manufacturers.csv")
df_man = pd.read_csv("/Users/olivianystrom/Desktop/Springboard/Capstone 3/doc8643Manufacturers.csv")

# %%
save_file = "/Users/olivianystrom/Desktop/Springboard/Capstone 3/Current_Flight_Data.csv"
df.to_csv(save_file)

# %%
open("/Users/olivianystrom/Desktop/Springboard/Capstone 3/Current_Flight_Data.csv")
df = pd.read_csv("/Users/olivianystrom/Desktop/Springboard/Capstone 3/Current_Flight_Data.csv")
df = df[['icao24', 'callsign', 'origin_country', 'last_contact',
       'longitude', 'latitude', 'baro_altitude', 'on_ground', 'velocity',
       'registration', 'manufacturericao', 'manufacturername', 'model',
       'typecode', 'serialnumber', 'linenumber', 'icaoaircrafttype',
       'operator', 'operatorcallsign', 'operatoricao', 'operatoriata', 'owner',
       'testreg', 'registered', 'built', 'firstflightdate', 'engines', 'notes',
       'categoryDescription']]
df.columns = df.columns.str.upper()
df.dtypes
# Out:
# ICAO24                  object
# CALLSIGN                object
# ORIGIN_COUNTRY          object
# LAST_CONTACT             int64
# LONGITUDE              float64
# LATITUDE               float64
# BARO_ALTITUDE          float64
# ON_GROUND                 bool
# VELOCITY               float64
# REGISTRATION            object
# MANUFACTURERICAO        object
# MANUFACTURERNAME        object
# MODEL                   object
# TYPECODE                object
# SERIALNUMBER            object
# LINENUMBER              object
# ICAOAIRCRAFTTYPE        object
# OPERATOR                object
# OPERATORCALLSIGN        object
# OPERATORICAO            object
# OPERATORIATA            object
# OWNER                   object
# TESTREG                 object
# REGISTERED              object
# BUILT                   object
# FIRSTFLIGHTDATE         object
# ENGINES                 object
# NOTES                   object
# CATEGORYDESCRIPTION     object
# dtype: object

# %%
from snowflake.connector import connect
from snowflake.connector import DictCursor
from snowflake.connector.pandas_tools import write_pandas
import pyarrow.parquet as pq
import os
from dotenv import load_dotenv
# Out:
# /Users/olivianystrom/opt/anaconda3/lib/python3.8/site-packages/snowflake/connector/options.py:96: UserWarning: You have an incompatible version of 'pyarrow' installed (8.0.0), please install a version that adheres to: 'pyarrow<6.1.0,>=6.0.0; extra == "pandas"'
#   warn_incompatible_dep(

# %%
load_dotenv()
snowflake_password = os.getenv('snowflake_password')
snowflake_user = os.getenv('snowflake_user')

# %%
print(snowflake_user)
print(snowflake_password)
# Out:
# osnystrom
# *gw!5DNVrCa*8oW9Vxc6Jg

# %%
def retrieve_conn():
    return connect(
        warehouse='COMPUTE_WH',
        account='st51563.us-central1.gcp', 
        database='PC_DBT_DB',
        schema='FLIGHT_TRACKING',
        user=snowflake_user,
        password=snowflake_password,
)

# %%
cnx = retrieve_conn()

# %%
success, nchunks, nrows, _ = write_pandas(cnx, df, 'FLIGHT_TRACKING_TABLE')
print(success)
print(nchunks)
print(nrows)
# Out:
# True
# 1
# 5944

# %%
success, nchunks, nrows, _ = write_pandas(cnx, df_emergent, 'EMERGENCY_FLIGHT_TRACKING')
print(success)
print(nchunks)
print(nrows)
# Out:
# True
# 1
# 830

# %%
success, nchunks, nrows, _ = write_pandas(cnx, df_meta, 'FLIGHT_METADATA_TABLE')
print(success)
print(nchunks)
print(nrows)
# Out:
# True
# 1
# 469999

# %%
success, nchunks, nrows, _ = write_pandas(cnx, covid_df, 'COVID_FLIGHT_TABLE')
print(success)
print(nchunks)
print(nrows)

# %%
covid_df.shape

# %%
covid_201904.shape
